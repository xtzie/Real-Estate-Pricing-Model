# %%
import pandas as pd

from sklearn.datasets import california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
housing_data = california_housing.fetch_california_housing()
X = pd.DataFrame(housing_data.data, columns = housing_data.feature_names)
y = housing_data.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.8, random_state = 42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_train)

plt.figure(figsize = (10,6))

plt.scatter(predictions, y_train)
plt.xlabel('predictions')
plt.ylabel('actual')
predictions
#x-axis first, then y-axis
# Out:
# array([ 990.73493893, 1568.95855857, 1810.18018628, ..., 2026.45968291,
#        2851.1248013 , 2256.27594667])

# %% [markdown]
# how to tune xgboost model:
# - work on subset of features
# - change sampling methodology
# - definition of outliers (filter out low values, if it's an actual loss you take the loss,
# or filter out the high values, because they skew your mean)
# - smaller company = usually use logistic regression
# - med sized = xgboost, random forest
# - large deep learning companies = deep learning networks, have phd candidates who are tuning the model
