# %%
# companies_to_apply_list.remove('Zillow')
# companies_to_apply_list += ['Redfin']

from bs4 import BeautifulSoup
import requests

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
import time, os

import pandas as pd
from collections import OrderedDict
import pickle

# %%
###creating lists to scrape timing data of zip codes to googleplex OR SF city

#zipcodelist.csv created from 'coreframe_thankyouGod_thankyouredfin.ipynb'
zipcodelist = pd.read_csv('zipcodelist.csv', header = None)
zipcodelist.columns = ['zipcode']
#header = None the syntax you need if first row is a value too

#how to filter out zipcodes that are wrong (e.g 3 digits instead of 5) and drop them?
# simple syntax for this somewhat elusive

#empty list for urls
sfurllist = {}
googleurllist ={}

#looping through and creating url lists
for zipcode in zipcodelist['zipcode']:
    if len(str(zipcode)) == 5:
        url = 'https://www.google.com/maps/dir/' + str(zipcode) + '/Salesforce+Tower,+415+Mission+St,+San+Francisco,+CA+94105/'
        sfurllist[zipcode] = url
        
for zipcode in zipcodelist['zipcode']:
    if len(str(zipcode)) == 5:
        url = 'https://www.google.com/maps/dir/' + str(zipcode) + '/Googleplex,+1600+Amphitheatre+Pkwy,+Mountain+View,+CA+94043/'
        googleurllist[zipcode] = url

# %%
#PREPARING WEBDRIVER#

chromedriver = "/home/xtzie/anaconda3/pkgs/python-chromedriver_edited(copy)/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver #SYNTAX
driver = webdriver.Chrome(chromedriver)

# %%
import re

def gettimetaken(string):
    endindex = string.find('<')
    return string[:endindex]
#python indexing works quite elegantly, start index includes the no. itself. end index does not

traveltimings = pd.DataFrame(columns = ['zipcode', 'traveltimetosf', 'traveltimetogoogleplex'])

# rmb.items() needed to loop through a dict!!!!
# for zipcode, xtz in googleurllist.items():
#     url = xtz
#     #stores html & js data as a string
#     chromedriver = "/home/xtzie/anaconda3/pkgs/python-chromedriver_edited(copy)/chromedriver" # path to the chromedriver executable
#     os.environ["webdriver.chrome.driver"] = chromedriver #SYNTAX
#     driver = webdriver.Chrome(chromedriver)
#     driver.get(url)
#     driver.page_source[:999999999999999999999999999]
#     soup = BeautifulSoup(driver.page_source, 'html.parser')
#     soupstring = str(soup)
#     time.sleep(1.5)
#     #since it's java script, you're loading the page, then parsing it as a string
#     # after parsing as a string, use regex to search for that specific code line 
#     #(that hopefully is uniform throughout iterations)
#     #then get the term after that
#     # put it into a frame, matched with the ZIP code or longitude/latitude
#     # sample string with travel data:
#     # <span jstcache="309">22 min</span>
#     try:
#         soupstring = str(soup)
#         startindex = re.search('jstcache="308"', soupstring).end() + 1
#         timetakenstring = soupstring[startindex:startindex + 20]
#         x = gettimetaken(timetakenstring)
#         print(zipcode, x)
#         traveltimings  = traveltimings.append({'zipcode': zipcode, 'traveltimetogoogleplex': x}, ignore_index = True)
#         driver.close()
#     except:
#         driver.close()
#     time.sleep(1.5)
# Out:
# 94103 55 min
# 94107 50 min
# 94117 1 h 2 min
# 94112 51 min
# 94115 1 h 10 min
# 94110 52 min
# 94108 1 h 8 min
# 94114 59 min
# 94122 1 h
# 94105 1 h 2 min
# 94116 57 min
# 94109 1 h 7 min
# 94131 56 min
# 94133 1 h 14 min
# 94132 51 min
},{"code":"RW","name":"My Starbucks Rewards"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"target-express-ocean-avenue-1830-ocean-ave-san-francisco-ca-94112-us"},{"recommendation":{},"storeNumber":"52031-280209","id":"1019235","name":"Target SF Stonestown T-3264","phoneNumber":"415-680-2914","coordinates":{"latitude":37.726518,"longitude":-122.476895},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"233 Winston Dr","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"94132"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 9:00 PM","addressLines":["233 Winston Dr","San Francisco, CA 94132"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"8:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"8:00 AM to 9:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"LB","name":"LaBoulange"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"target-sf-stonestown-t-3264-233-winston-dr-san-francisco-ca-94132-us"},{"recommendation":{},"storeNumber":"79532-102919","id":"17332","name":"Safeway - Noriega #985","phoneNumber":null,"coordinates":{"latitude":37.75407,"longitude":-122.488791},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"2350 Noriega Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941224240"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 6:30 PM","addressLines":["2350 Noriega Street","San Francisco, CA 94122"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"6:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"6:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"6:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"6:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"6:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"6:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"6:30 AM to 6:30 PM","open":true,"holiday":""}],"features":[{"code":"WF","name":"Wireless Hotspot"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"}],"slug":"safeway-noriega-985-2350-noriega-street-san-francisco-ca-941224240-us"},{"recommendation":{},"storeNumber":"74816-73618","id":"9404","name":"Safeway - San Francisco #667","phoneNumber":"415-824-7744","coordinates":{"latitude":37.74374,"longitude":-122.438769},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"5290 Diamond Heights Blvd","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941312118"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 7:00 PM","addressLines":["5290 Diamond Heights Blvd","San Francisco, CA 94131"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"}],"slug":"safeway-san-francisco-667-5290-diamond-heights-blvd-san-francisco-ca-9413121"},{"recommendation":{},"storeNumber":"629-414","id":"16030","name":"9th & Irving","phoneNumber":"(415) 664-8340","coordinates":{"latitude":37.764167,"longitude":-122.466005},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"744 Irving Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941222410"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 6:30 PM","addressLines":["744 Irving Street","San Francisco, CA 94122"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:00 AM to 7:30 PM","open":true,"holiday":""}],"features":[{"code":"CL","name":"Starbucks Reserve-Clover Brewed"},{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"VS","name":"Verismo"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"9th-irving-744-irving-street-san-francisco-ca-941222410-us"},{"recommendation":{},"storeNumber":"5584-1613","id":"8843","name":"19th and Irving","phoneNumber":"4152427970","coordinates":{"latitude":37.763719,"longitude":-122.477464},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"1800 Irving Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941221818"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 8:00 PM","addressLines":["1800 Irving Street","San Francisco, CA 94122"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"4:30 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 8:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"4:00 AM to 7:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"VS","name":"Verismo"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"19th-and-irving-1800-irving-street-san-francisco-ca-941221818-us"},{"recommendation":{},"storeNumber":"9215-9397","id":"18552","name":"350 Parnassus","phoneNumber":"(415) 665-6406","coordinates":{"latitude":37.764175,"longitude":-122.456383},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"350 Parnassus Street","streetAddressLine2":null,"streetAddressLine3":"Parnassus Heights Medical Center","city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941173608"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 3:00 PM","addressLines":["350 Parnassus Street","San Francisco, CA 94117"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"7:00 AM to 3:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:30 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:30 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:30 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"6:00 AM to 5:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"VS","name":"Verismo"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"LU","name":"Lunch"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"350-parnassus-350-parnassus-street-parnassus-heights-medical-cen"},{"recommendation":{},"storeNumber":"545-488","id":"12166","name":"24th & Noe","phoneNumber":"(415) 826-1118","coordinates":{"latitude":37.75134,"longitude":-122.431704},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"3995 24th Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941143703"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 9:30 PM","addressLines":["3995 24th Street","San Francisco, CA 94114"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 9:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""}],"features":[{"code":"CL","name":"Starbucks Reserve-Clover Brewed"},{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"24th-noe-3995-24th-street-san-francisco-ca-941143703-us"},{"recommendation":{},"storeNumber":"9212-9394","id":"16848","name":"4094 18th St.","phoneNumber":"(415) 626-6263","coordinates":{"latitude":37.761034,"longitude":-122.434611},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"4094 18th Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941142534"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 9:00 PM","addressLines":["4094 18th Street","San Francisco, CA 94114"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"6:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:30 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:30 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:30 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:30 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 10:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"4094-18th-st-4094-18th-street-san-francisco-ca-941142534-us"},{"recommendation":{},"storeNumber":"5395-1145","id":"16589","name":"Masonic at Fulton - S.F.","phoneNumber":"(415) 474-8930","coordinates":{"latitude":37.77573,"longitude":-122.446276},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"1799 Fulton Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941171202"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 7:00 PM","addressLines":["1799 Fulton Street","San Francisco, CA 94117"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:00 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:00 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:00 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:00 AM to 6:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:00 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"masonic-at-fulton-s-f-1799-fulton-street-san-francisco-ca-941171202-us"},{"recommendation":{},"storeNumber":"5510-992","id":"13355","name":"5455 Geary Blvd. - WFB","phoneNumber":"(415) 386-8813","coordinates":{"latitude":37.780175,"longitude":-122.478147},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"5455 Geary Blvd","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941212383"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 7:30 PM","addressLines":["5455 Geary Blvd","San Francisco, CA 94121"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:00 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:00 AM to 7:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"VS","name":"Verismo"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"LU","name":"Lunch"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"5455-geary-blvd-wfb-5455-geary-blvd-san-francisco-ca-941212383-us"},{"recommendation":{},"storeNumber":"74151-24429","id":"11053","name":"Safeway-San Francisco #1507","phoneNumber":"415-861-7660","coordinates":{"latitude":37.768828,"longitude":-122.428682},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"2020 Market St.","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941141314"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 7:30 PM","addressLines":["2020 Market St.","San Francisco, CA 94114"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 7:30 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"}],"slug":"safeway-san-francisco-1507-2020-market-st-san-francisco-ca-941141314-us"},{"recommendation":{},"storeNumber":"5408-100759","id":"8626","name":"John Daly & Westlake Center","phoneNumber":"650-994-2948","coordinates":{"latitude":37.700764,"longitude":-122.483215},"regulations":[],"address":{"streetAddressLine1":"332 Westlake Center","streetAddressLine2":"332","streetAddressLine3":"Westlake Shopping Center","city":"Daly City","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"940151431"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open 24 hours","addressLines":["332 Westlake Center","332","Daly City, CA 94015"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""},{"dayName":"Thursday","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""},{"dayName":"Friday","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""},{"dayName":"Saturday","hours":"12:00 AM to 12:00 AM","open":true,"holiday":""}],"features":[{"code":"hrs24","name":"Open 24 hours per day","filterable":true,"public":true},{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"john-daly-westlake-center-332-westlake-center-westlake-shopping-center-daly-"},{"recommendation":{},"storeNumber":"74958-102357","id":"65861","name":"Safeway - Daly City #3031","phoneNumber":"650-755-0576","coordinates":{"latitude":37.699386,"longitude":-122.481414},"regulations":[],"address":{"streetAddressLine1":"601 Westlake Center","streetAddressLine2":null,"streetAddressLine3":null,"city":"Daly City","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"940151434"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 7:00 PM","addressLines":["601 Westlake Center","Daly City, CA 94015"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"6:00 AM to 7:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"PS","name":"Playbook Store System"}],"slug":"safeway-daly-city-3031-601-westlake-center-daly-city-ca-940151434-us"},{"recommendation":{},"storeNumber":"19656-165924","id":"1006015","name":"Target SF West T-2768","phoneNumber":"415-796-5280","coordinates":{"latitude":37.782075,"longitude":-122.447082},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":
30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:00 AM to 8:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:00 AM to 8:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"6:00 AM to 8:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"SQ","name":"tbd"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"4th-market-s-f-780-market-street-san-francisco-ca-941022514-us"},{"recommendation":{},"storeNumber":"14393-110285","id":"10551","name":"Powell & Sutter","phoneNumber":"415-956-2321","coordinates":{"latitude":37.789077,"longitude":-122.408428},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"462 Powell Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941021504"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 10:00 PM","addressLines":["462 Powell Street","San Francisco, CA 94102"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 9:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 9:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 9:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 9:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 10:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 10:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"powell-sutter-462-powell-street-san-francisco-ca-941021504-us"},{"recommendation":{},"storeNumber":"5757-13320","id":"12349","name":"390 Stockton at Sutter (Union Sq)","phoneNumber":"415-989-1637","coordinates":{"latitude":37.789359,"longitude":-122.406823},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"390 Stockton Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941084670"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 10:00 PM","addressLines":["390 Stockton Street","San Francisco, CA 94108"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"SQ","name":"tbd"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"390-stockton-at-sutter-union-sq-390-stockton-street-san-francisco-ca-941084670-us"},{"recommendation":{},"storeNumber":"74482-94458","id":"12356","name":"Safeway-San Francisco #2606","phoneNumber":"415-633-1001","coordinates":{"latitude":37.776789,"longitude":-122.393907},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"298 King Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941071702"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 7:00 PM","addressLines":["298 King Street","San Francisco, CA 94107"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"}],"slug":"safeway-san-francisco-2606-298-king-street-san-francisco-ca-941071702-us"},{"recommendation":{},"storeNumber":"4147-153384","id":"18807","name":"Target Colma T-320","phoneNumber":"650-992-8433","coordinates":{"latitude":37.673284,"longitude":-122.464434},"regulations":[],"address":{"streetAddressLine1":"5001 Junipero Serra Blvd","streetAddressLine2":null,"streetAddressLine3":null,"city":"Colma","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"940143217"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 9:00 PM","addressLines":["5001 Junipero Serra Blvd","Colma, CA 94014"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"target-colma-t-320-5001-junipero-serra-blvd-colma-ca-940143217-us"}],"coordinates":{"lat":37.74122,"lng":-122.46665},"includesRecommendedLocations":false},"moreResultsAvailable":true,"selectedStoreId":"9128","expandedStoreId":null}},"router":{"location":{"pathname":"/store-locator/","search":"?map=37.74122,-122.46665,12z","hash":"","key":"fbcuvn","query":{"map":"37.74122,-122.46665,12z"}},"action":"POP"},"routes":{"current":{"pathname":"/store-locator/","hash":"","search":"?map=37.74122,-122.46665,12z","state":{},"route":"/store-locator*","params":{"0":"/"},"query":{"map":"37.74122,-122.46665,12z"},"result":{"usesCrateLayout":true}},"previous":null,"routes":{"/store-locator*":{"usesCrateLayout":true}}},"bottomSheet":{"bottomSheetRoutes":[],"bottomSheetReturnUrl":null},"overlay":{"overlaysOpenedByUrlHash":[]},"config":{"universal":{"bffBaseUrl":"","chasePay":{"chasePayEnabled":true,"url":"https://pwc.chase.com/pwc/checkout/js/v20170521/list.action?type=raw&applId=PWC&channelId=CWC&version=1"},"payPal":{"enabled":true,"url":"https://www.paypal.com/sdk/js?client-id=AXjQJ2vHhgpu7DYUrE1IerCOOp9y-d8dSIMEIkc49ckjO9M04AehA8qm5jm0FIV7kO3CEtzZ8e-dp8-2&vault=true&intent=authorize&commit=false"},"securePayment":{"securePaymentOrigin":"https://globalsecureui.starbucks.com"},"optimizely":{"environment":"production","sdkKey":"28Mn9riXNWZ7tLED1Mjbpf","cookieName":"ux_exp_id","cookieMaxAge":31557600000,"dataFileTimeout":500,"logLevel":4},"clientErrorLogging":false,"risk":{"platform":"Web","ccAgentName":"WebApp","deviceFingerprinting":{"iovationGlobalName":"IGLOO","maxDelay":5000}},"staticUrls":{"assets":{"host":"","path":"weblx/assets"},"images":{"host":"","path":"weblx/images"},"static":{"host":"https://assets.web.starbucksassets.com","path":"weblx/static"}},"shapeScript":"/vendor/static/vendor2.js","communicationPreferences":{"enabled":true,"appPath":"/settings/communication-preferences","legacyPath":"/account/profile/contactprefs","topics":{"sbuxEmail":"sbux_email","sbuxGeneralEmail":"sbux_gen_email","sbuxPersonalizedEmail":"sbux_per_email","sbuxPostalMail":"sbux_mail","businessPartnerEmail":"affiliate_email"}},"userSelectedLanguageCookieName":".SbuxLang","enableMfaFeatures":true,"oauthMfaChallengeErrorCode":"101010","guestGiftingForAddCardEnabled":false},"supportedLocales":{"en-US":{"name":"English","coreAppBaseUrl":"https://app.starbucks.com","legacyBaseUrl":"https://www.starbucks.com","coreAppHasSignin":true,"countryName":"U.S.","currency":"USD","secureUiUrlSrc":"https://secureui.starbucks.com","securePaymentFormPath":"/SecureUI/v2/paymentinstruments/guest/en/us/single-use"},"en-IE":{"name":"English","legacyBaseUrl":"https://www.starbucks.ie","defaultSigninRedirect":"/account/home","coreAppHasSignin":false,"countryName":"Ireland","currency":"GBP"},"en-GB":{"name":"English","legacyBaseUrl":"https://www.starbucks.co.uk","defaultSigninRedirect":"/account/home","coreAppHasSignin":false,"countryName":"UK","currency":"GBP"},"en-CA":{"name":"English","coreAppBaseUrl":"https://app.starbucks.ca","legacyBaseUrl":"https://www.starbucks.ca","coreAppHasSignin":true,"altLang":"fr-CA","multiLangDefault":"en-CA","countryName":"Canada","currency":"CAD","secureUiUrlSrc":"https://secureui.starbucks.com","secureUiProxyUrl":"/bff/payment-method/secureui-url-proxy","secureUiShouldProxy":true,"securePaymentFormPath":"/SecureUI/v2/paymentinstruments/guest/en/ca/single-use"},"fr-CA":{"name":"Français","coreAppBaseUrl":"https://app.starbucks.ca","legacyBaseUrl":"https://fr.starbucks.ca","coreAppHasSignin":true,"altLang":"en-CA","multiLangDefault":"en-CA","countryName":"Canada","currency":"CAD","secureUiUrlSrc":"https://secureui.starbucks.com","secureUiProxyUrl":"/bff/payment-method/secureui-url-proxy","secureUiShouldProxy":true,"securePaymentFormPath":"/SecureUI/v2/paymentinstruments/guest/fr/ca/single-use"},"de-DE":{"name":"Deutsch","legacyBaseUrl":"https://www.starbucks.de","defaultSigninRedirect":"/account/home","coreAppHasSignin":false,"countryName":"Deutschland","currency":"EUR"},"fr-FR":{"name":"Français","legacyBaseUrl":"https://www.starbucks.fr","defaultSigninRedirect":"/account/home","coreAppHasSignin":false,"countryName":"France","currency":"EUR"},"pt-BR":{"name":"Português","legacyBaseUrl":"https://www.starbucks.com.br","defaultSigninRedirect":"/account/home","coreAppHasSignin":false,"countryName":"Brasil","currency":"BRL"}},"mainNavLinks":[{"name":"Menu","url":"/menu","data-e2e":"dotComHamburgerNavMenu","subNavItems":[{"name":"All products","url":"/menu","data-e2e":"dotComHamburgerNavMenuLink"},{"name":"Featured","url":"https://www.starbucks.com/menu/featured","data-e2e":"dotComHamburgerNavFeaturedLink"},{"name":"Previous","url":"/menu/previous","data-e2e":"dotComHamburgerNavPreviousLink"},{"name":"Favorites","url":"/menu/favorites","data-e2e":"dotComHamburgerNavFavoritesLink"}]},{"name":"Rewards","url":"/rewards","data-e2e":"dotComHamburgerNavRewards"},{"name":"Gift Cards","url":"/shop/card/egift","data-e2e":"dotComHamburgerNavMenuGift"}],"accountNav":{"name":"Account","data-e2e":"dotComHamburgerNavAccountPushViewBtn","subNavItems":[{"name":"Card management","url":"/cards"},{"name":"My Rewards","url":"/rewards"},{"name":"History","url":"/activity"},{"name":"Personal info","url":"/personal"},{"name":"Payment methods","url":"/payment-method"},{"name":"Settings","url":"/settings"}]},"signOutButton":{"name":"Sign out","data-e2e":"dotComHamburgerNavMenuSignout"},"footerNavLinks":[{"name":"Responsibility","url":"https://www.starbucks.com/responsibility"},{"name":"Web Accessibility","url":"https://www.starbucks.com/about-us/company-information/online-policies/web-accessibility"},{"name":"Privacy Policy","url":"https://www.starbucks.com/about-us/company-information/online-policies/privacy-policy"},{"name":"Terms of Use","url":"https://www.starbucks.com/about-us/company-information/online-policies/terms-of-use"}],"onlinePolicyUrls":{"cardsTermsAndConditions":"https://www.starbucks.com/card/card-terms-and-conditions","customerServiceUrl":"https://customerservice.starbucks.com","customerServiceMfaHelpUrl":"https://customerservice.starbucks.com/app/answers/list/p/148","privacyStatementContactUsUrl":"https://www.starbucks.com/customer-service/contact-us","privacyStatementUrl":"https://www.starbucks.com/about-us/company-information/online-policies/privacy-policy","rewardsTermsOfUse":"https://www.starbucks.com/rewards/terms","termsOfUseUrl":"https://www.starbucks.com/about-us/company-information/online-policies/terms-of-use"},"numericPostalCode":true,"addressFieldNames":["AddressLineFields","CityField","CountrySubdivisionSelect","PostalCodeField"],"countrySubdivisions":{"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware","DC":"District of Columbia","FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland","MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina","ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington","WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"},"chaseCreditBasePath":"/starbucks-rewards/credit-card","chasePrepaidBasePath":"/starbucks-rewards/prepaid-card","communicationPreferences":{"email":["sbux_email","affiliate_email"],"mail":["sbux_mail"]},"showLinkToProfileFromCommunicationPreferences":true,"chasePayAvailable":true,"showSimplifiedAccountCreate":true,"selectBirthdayMonthFirst":true,"supportsMenuAndOrdering":true,"phoneNumber":{"countryCode":"01","length":"10"},"footer":{"primaryLinkListsHeadingProps":{"size":"xs","tagName":"h3"},"primaryLinkLists":[{"headingText":"About Us","ariaExpandButtonLabel":"Expand About Us","links":[{"text":"Our Heritage","href":"https://www.starbucks.com/about-us/company-information"},{"text":"Our Coffee","href":"https://www.starbucks.com/coffee"},{"text":"Stories and News","href":"https://stories.starbucks.com/"},{"text":"Investor Relations","href":"https://investor.starbucks.com"},{"text":"Policies and Standards","href":"https://www.starbucks.com/responsibility/global-report/policies"},{"text":"Customer Service","href":"https://customerservice.starbucks.com/"}]},{"headingText":"Careers","ariaExpandButtonLabel":"Expand Careers","links":[{"text":"Culture and Values","href":"https://www.starbucks.com/careers/working-at-starbucks/culture-and-values"},{"text":"Diversity and Inclusion","href":"https://www.starbucks.com/responsibility/community/diversity-and-inclusion"},{"text":"College Achievement Plan","href":"https://www.starbucks.com/careers/working-at-starbucks/education"},{"text":"U.S. Careers","href":"https://www.starbucks.com/careers/"},{"text":"International Careers","href":"https://www.starbucks.com/careers/international-careers"}]},{"headingText":"Social Impact","ariaExpandButtonLabel":"Expand Social Impact","links":[{"text":"Ethical Sourcing","href":"https://www.starbucks.com/responsibility/sourcing"},{"text":"Leading in Sustainability","href":"https://www.starbucks.com/responsibility/environment"},{"text":"Strengthening Communities","href":"https://www.starbucks.com/responsibility/community"},{"text":"Creating Opportunities","href":"https://www.starbucks.com/responsibility/community/opportunity-youth"},{"text":"Global Social Impact Report","href":"https://www.starbucks.com/responsibility/global-report"}]},{"headingText":"For Business Partners","ariaExpandButtonLabel":"Expand For Business Partners","links":[{"text":"Landlord Support Center","href":"https://www.starbucks.com/business/landlord-faq"},{"text":"Suppliers","href":"https://www.starbucks.com/business/suppliers"},{"text":"Corporate Gift Card Sales","href":"https://www.starbuckscardb2b.com/","target":"_blank"}]},{"headingText":"Ways To Order","ariaExpandButtonLabel":"Expand Ways To Order","links":[{"text":"Order on the Web","href":"https://www.starbucks.com/menu"},{"text":"Download the App","href":"https://www.starbucks.com/coffeehouse/mobile-order"},{"text":"Delivery","href":"https://delivery.starbucks.com/","target":"_blank"},{"text":"Google Assistant","href":"https://www.starbucks.com/promo/googleassistant"}]}],"socialMediaIcons":[{"name":"spotify","url":"https://open.spotify.com/user/starbucks"},{"name":"facebook","url":"https://facebook.com/starbucks"},{"name":"pinterest","url":"https://www.pinterest.com/starbucks/"},{"name":"instagram","url":"https://instagram.com/starbucks"},{"name":"youtube","url":"https://www.youtube.com/starbucks"},{"name":"twitter","url":"https://twitter.com/starbucks/"}],"secondaryLinkList":[{"text":"Privacy Policy","href":"https://www.starbucks.com/about-us/company-information/online-policies/privacy-policy"},{"text":"Terms of Use","href":"https://www.starbucks.com/about-us/company-information/online-policies/terms-of-use"},{"text":"CA Supply Chain Act","href":"https://globalassets.starbucks.com/assets/A2A072E3411C4A6ABAEB8D6BCF286F43.pdf"},{"text":"Submit Your Idea","href":"https://ideas.starbucks.com/"}]},"mapDefaults":{"lat":39.635307,"lng":-101.337891,"zoom":5},"limit":50,"panThreshold":1.6,"searchRadius":50,"searchRadiusLimit":250,"singleLocationZoom":15,"zoomThreshold":6,"geolocationThreshold":1600,"googleMapsUrl":"https://maps.googleapis.com/maps/api/js?v=3&client=gme-starbuckscorporation&libraries=places&language=en-US","addressFields":[{"fieldName":"streetAddressLine1","postFieldCharacter":"LINE_BREAK"},{"fieldName":"streetAddressLine2","postFieldCharacter":"LINE_BREAK"},{"fieldName":"city","postFieldCharacter":", "},{"fieldName":"countrySubdivisionCode","postFieldCharacter":" "},{"fieldName":"postalCode","postFieldCharacter":"LINE_BREAK"}],"features":[{"code":"ON","name":"Open Now","filterable":true,"public":true},{"code":"DT","name":"Drive-Thru","filterable":true,"public":true},{"code":"hrs24","name":"Open 24 hours per day","filterable":true,"public":true},{"code":"XO","name":"Mobile Order and Pay","filterable":true,"public":true},{"code":"UP","name":"Starbucks Pickup","filterable":false,"public":true},{"code":"CL","name":"Starbucks Reserve-Clover Brewed","filterable":true,"public":true},{"code":"GO","name":"Google Wi-Fi","filterable":true,"public":true},{"code":"EM","name":"Starbucks Evenings","filterable":false,"public":true},{"code":"CL","name":"Starbucks Reserve","filterable":false,"public":true},{"code":"WA","name":"Oven-warmed Food","filterable":false,"public":true},{"code":"DR","name":"Digital Rewards","filterable":true,"public":true},{"code":"CD","name":"Mobile Payment","filterable":false,"public":true},{"code":"VS","name":"Verismo","filterable":false,"public":true},{"code":"11","name":"Brilliant Collection","filterable":false,"public":false},{"code":"12","name":"Dot Local Collection","filterable":false,"public":false},{"code":"FZ","name":"Fizzio Handcrafted Sodas","filterable":false,"public":true},{"code":"LB","name":"LaBoulange","filterable":false,"public":true},{"code":"LU","name":"Lunch","filterable":false,"public":false},{"code":"MX","name":"Music Experience","filterable":false,"public":false},{"code":"PS","name":"Playbook Store System","filterable":false,"public":false},{"code":"10","name":"Premium Collection","filterable":false,"public":false},{"code":"13","name":"Starbucks Reserve Christmas Blend","filterable":false,"public":false},{"code":"WC","name":"Wireless Charging","filterable":false,"public":false},{"code":"SD","name":"Street Delivery","filterable":false,"public":false},{"code":"NB","name":"Nitro Cold Brew","filterable":true,"public":true},{"code":"MC","name":"Mercato","filterable":false,"public":true}],"metric":false},"eventSource":{},"hamburgerNav":{"isOpen":false},"message":null,"dialog":null,"time":1579462803790,"topSheet":[],"viewport":null,"scripts":{},"storeLocator":{"expandedStoreState":null,"locationState":{"error":null,"includesRecommendedLocations":false,"loading":false,"locations":[{"recommendation":{},"storeNumber":"5271-845","id":"9128","name":"100 West Portal/Vicente","phoneNumber":"(415) 664-8370","coordinates":{"latitude":37.739684,"longitude":-122.467323},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":
],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"6:00 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 6:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"4:30 AM to 6:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"VS","name":"Verismo"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"3rd-evans-3801-3rd-street-bayview-plaza-san-francisco-ca-941"},{"recommendation":{},"storeNumber":"14311-115765","id":"10784","name":"Owens & 16th","phoneNumber":"415-252-7423","coordinates":{"latitude":37.767065,"longitude":-122.39366},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"1700 Owens Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941580004"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":false,"openStatusText":"Closed","addressLines":["1700 Owens Street","San Francisco, CA 94158"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"Closed","open":false,"holiday":""},{"dayName":"Tomorrow","hours":"4:00 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:00 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:00 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:00 AM to 5:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:00 AM to 4:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"Closed","open":false,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"owens-16th-1700-owens-street-san-francisco-ca-941580004-us"},{"recommendation":{},"storeNumber":"509-452","id":"11720","name":"Union & Laguna","phoneNumber":"(415) 921-4049","coordinates":{"latitude":37.797642,"longitude":-122.430404},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"1899 Union Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941234307"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 8:00 PM","addressLines":["1899 Union Street","San Francisco, CA 94123"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 7:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""}],"features":[{"code":"CL","name":"Starbucks Reserve-Clover Brewed"},{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"},{"code":"UE","name":"tbd - Uber Eats"}],"slug":"union-laguna-1899-union-street-san-francisco-ca-941234307-us"},{"recommendation":{},"storeNumber":"531-475","id":"15803","name":"Chestnut Reserve Store","phoneNumber":"(415) 673-6781","coordinates":{"latitude":37.800645,"longitude":-122.43854},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"2132 Chestnut Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941232709"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 8:00 PM","addressLines":["2132 Chestnut Street","San Francisco, CA 94123"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"6:00 AM to 8:00 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"GO","name":"Google Wi-Fi"}],"slug":"chestnut-reserve-store-2132-chestnut-street-san-francisco-ca-941232709-us"},{"recommendation":{},"storeNumber":"10891-85603","id":"10371","name":"865 Market - SF Centre","phoneNumber":"415-348-0940","coordinates":{"latitude":37.784131,"longitude":-122.407362},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"865 Market Street","streetAddressLine2":"C 26A","streetAddressLine3":"San Francisco Centre","city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941031900"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 7:00 PM","addressLines":["865 Market Street","C 26A","San Francisco, CA 94103"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"8:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:00 AM to 7:00 PM","open":true,"holiday":"Martin Luther King Day"},{"dayName":"Tuesday","hours":"5:00 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"6:00 AM to 9:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"SQ","name":"tbd"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"865-market-sf-centre-865-market-street-san-francisco-centre-san-francis"},{"recommendation":{},"storeNumber":"5404-1241","id":"12071","name":"Geary & Taylor - San Francisco","phoneNumber":"(415) 922-9086","coordinates":{"latitude":37.787177,"longitude":-122.410778},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"442 Geary Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941021223"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 8:30 PM","addressLines":["442 Geary Street","San Francisco, CA 94102"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 8:30 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 9:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"geary-taylor-san-francisco-442-geary-street-san-francisco-ca-941021223-us"},{"recommendation":{},"storeNumber":"5649-1926","id":"11405","name":"Hotel Nikko","phoneNumber":"415-296-9056","coordinates":{"latitude":37.786171,"longitude":-122.409059},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"222 Mason St","streetAddressLine2":null,"streetAddressLine3":"Nikko Hotel","city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941022115"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"CO","open":true,"openStatusText":"Open until 11:00 PM","addressLines":["222 Mason St","San Francisco, CA 94102"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"4:00 AM to 11:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:00 AM to 11:30 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:00 AM to 11:30 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:00 AM to 11:30 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:00 AM to 11:30 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:00 AM to 11:30 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"4:00 AM to 11:30 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"WF","name":"Wireless Hotspot"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"WC","name":"Wireless Charging"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":
],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"4:30 AM to 10:00 PM","open":true,"holiday":""}],"features":[{"code":"WA","name":"Oven-warmed Food"},{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"GO","name":"Google Wi-Fi"},{"code":"XO","name":"Mobile Order and Pay"},{"code":"MX","name":"Music Experience"},{"code":"NB","name":"Nitro Cold Brew"},{"code":"MC","name":"Mercato"},{"code":"LU","name":"Lunch"},{"code":"SQ","name":"tbd"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"PS","name":"Playbook Store System"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"390-stockton-at-sutter-union-sq-390-stockton-street-san-francisco-ca-941084670-us"},{"recommendation":{},"storeNumber":"74482-94458","id":"12356","name":"Safeway-San Francisco #2606","phoneNumber":"415-633-1001","coordinates":{"latitude":37.776789,"longitude":-122.393907},"regulations":[{"code":"requireBeveragePlasticsOptIn"}],"address":{"streetAddressLine1":"298 King Street","streetAddressLine2":null,"streetAddressLine3":null,"city":"San Francisco","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"941071702"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 7:00 PM","addressLines":["298 King Street","San Francisco, CA 94107"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"5:30 AM to 7:00 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"}],"slug":"safeway-san-francisco-2606-298-king-street-san-francisco-ca-941071702-us"},{"recommendation":{},"storeNumber":"4147-153384","id":"18807","name":"Target Colma T-320","phoneNumber":"650-992-8433","coordinates":{"latitude":37.673284,"longitude":-122.464434},"regulations":[],"address":{"streetAddressLine1":"5001 Junipero Serra Blvd","streetAddressLine2":null,"streetAddressLine3":null,"city":"Colma","countrySubdivisionCode":"CA","countryCode":"US","postalCode":"940143217"},"timeZoneInfo":{"currentTimeOffset":-480,"windowsTimeZoneId":"Pacific Standard Time","olsonTimeZoneId":"GMT-07:00 America/Los_Angeles"},"brandName":"Starbucks","ownershipTypeCode":"LS","open":true,"openStatusText":"Open until 9:00 PM","addressLines":["5001 Junipero Serra Blvd","Colma, CA 94014"],"mop":{"ready":false,"wait":null},"schedule":[{"dayName":"Today","hours":"7:00 AM to 9:00 PM","open":true,"holiday":""},{"dayName":"Tomorrow","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Tuesday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Wednesday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Thursday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Friday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""},{"dayName":"Saturday","hours":"8:00 AM to 10:00 PM","open":true,"holiday":""}],"features":[{"code":"CD","name":"Mobile Payment"},{"code":"DR","name":"Digital Rewards"},{"code":"LB","name":"LaBoulange"},{"code":"BA","name":"Bakery"},{"code":"RW","name":"My Starbucks Rewards"},{"code":"BE","name":"tbd - Blonde Espresso"}],"slug":"target-colma-t-320-5001-junipero-serra-blvd-colma-ca-940143217-us"}],"resultCoordinates":{"lat":37.74122,"lng":-122.46665},"selectedStoreId":"9128","highlightedStoreId":null,"locationQuery":{"lat":"37.74122","lng":"-122.46665"},"locationQueryUrl":"/bff/locations?lat=37.74122&lng=-122.46665","moreResultsAvailable":true,"placeName":"","placeNameNotFound":false,"fetchAtLocation":false,"shouldScroll":false,"geolocationSearch":false},"mapState":{"lat":"37.74122","lng":"-122.46665","zoomLevel":12,"mapInstance":null,"locatorControlsHeight":0,"locatorPageRectangle":null,"userOverride":true,"preventMovement":false,"coordinatesUpdated":false,"initialUrlZoomOutsideThreshold":false},"nearestLocationState":{"loading":false,"nearestNotFound":false,"nearestStoreCoordinates":null,"hasSearchedNearest":false},"selectedFeaturesState":[],"transportMethodsState":{"methods":["Car","Transit","Walk","Bike"],"selected":"Car"},"filterState":{"isOverlayOpen":false}},"user":{"sessionExpired":false,"loggedOut":false,"reAuthEligible":null,"profile":{"data":null,"loading":false,"lastFetch":null,"lastError":null,"mutationError":null,"redeemedRewards":0},"mfaFactors":{"data":null,"loading":false,"lastFetch":null,"lastError":null,"mutationError":null},"sessionMeta":null,"onboardingFlags":{"data":null,"loading":false,"lastFetch":null,"lastError":null,"mutationError":null},"chaseStatus":{"data":null,"loading":false,"lastFetch":null,"lastError":null,"mutationError":null},"betaFlags":{"data":null,"loading":false,"lastFetch":null,"lastError":null,"mutationError":null}}}

storedict = isthisalegitdict["previousAction"]["payload"]['data']['stores']

headers = []
for k in isthisalegitdict["previousAction"]["payload"]['data']['stores'][0]:
    headers += [k]

firstset = pd.DataFrame(storedict)

address_subheads = ['streetAddressLine1', 'city', 'countrySubdivisionCode', 'postalCode']

feature_subheads = ['CL', 'MC', 'NB', 'VS']


for addresssubvalue in address_subheads:
    firstset[addresssubvalue] = firstset['address'].map(lambda x: x[addresssubvalue]) #here x is a dictionary

for x in features:
    for dict,value in x.items():
        if value == 'WA':
            print('yes WA is there')
for code in feature_subheads:
    firstset[code] = firstset['features'].map(lambda features: [True for dict in features
                                                                for key,values in dict.items() 
                                                                if values == code])

firstset.drop(['recommendation', 'address', 'regulations', 'timeZoneInfo', 'brandName', 'open', 'openStatusText', 'mop', 'schedule', 'slug'], axis = 1, inplace = True)

firstset['postalCode'] = firstset['postalCode'].map(lambda x: x[:5])

firstset

# key, values for key,values in dict for dict in features
    
# firstset['CL']
# lambda x: [subvalue if subvalue == featuresubvalue for subvalue in x]
# firstset['city']
# firstset['streetAddress'] = firstset['address'].map(lambda x: x['streetAddressLine1'])

# total_stores = 0
# for k in isthisalegitdict["previousAction"]["payload"]['data']['stores']:
#     for headings, values in k.items():
        
#     print('BREAK')
#     total_stores += 1
# print(total_stores)
# Out:
# yes WA is there
#      storeNumber       id                                 name  \
# 0       5271-845     9128              100 West Portal/Vicente
# 1      5669-4251    16566               675 Portola - Miraloma
# 2     5851-27487     9270                  Stonestown Galleria
# 3   24324-233046  1009860        Target Express - Ocean Avenue
# 4   52031-280209  1019235          Target SF Stonestown T-3264
# 5   79532-102919    17332               Safeway - Noriega #985
# 6    74816-73618     9404         Safeway - San Francisco #667
# 7        629-414    16030                         9th & Irving
# 8      5584-1613     8843                      19th and Irving
# 9      9215-9397    18552                        350 Parnassus
# 10       545-488    12166                           24th & Noe
# 11     9212-9394    16848                        4094 18th St.
# 12     5395-1145    16589             Masonic at Fulton - S.F.
# 13      5510-992    13355               5455 Geary Blvd. - WFB
# ...

# %%
##create loop for all the zipcodes
#zip code list - for each zip code, input that into the string, and from the string, pull out the times associated with it.
